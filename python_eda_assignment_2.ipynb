# %% [markdown]
# <a href="https://colab.research.google.com/github/mzieba1/Phthon-EDA-assignment-2/blob/main/python_eda_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/chiharuishida/Tutorialdata/main/ad_dataset_withheaders.csv"
Ad = pd.read_csv(url)

# %%
Ad.head(10)
# Out:
#    Site_Time  Age  DailyTime  Gender AdClicking
# 0      68.95   35     256.09  Female         No
# 1      80.23   31     193.77    Male         No
# 2      69.47   26     236.50  Female         No
# 3      74.15   29     245.89    Male         No
# 4      68.37   35     225.58  Female         No
# 5      59.99   23     226.74    Male         No
# 6      88.91   33     208.36  Female         No
# 7      66.00   48     131.76    Male        Yes
# 8      74.53   30     221.51    Male         No
# 9      69.88   20     183.82    Male         No

# %%
Ad.describe
# Out:
# <bound method NDFrame.describe of      Site_Time  Age  DailyTime  Gender AdClicking
# 0        68.95   35     256.09  Female         No
# 1        80.23   31     193.77    Male         No
# 2        69.47   26     236.50  Female         No
# 3        74.15   29     245.89    Male         No
# 4        68.37   35     225.58  Female         No
# ..         ...  ...        ...     ...        ...
# 995      72.97   30     208.58    Male        Yes
# 996      51.30   45     134.42    Male        Yes
# 997      51.63   51     120.37    Male        Yes
# 998      55.55   19     187.95  Female         No
# 999      45.01   26     178.35  Female        Yes
#
# [1000 rows x 5 columns]>

# %%
Ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Site_Time   1000 non-null   float64
#  1   Age         1000 non-null   int64
#  2   DailyTime   1000 non-null   float64
#  3   Gender      1000 non-null   object
#  4   AdClicking  1000 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
Ad['Site_Time'].value_counts()
# Out:
# 77.05    3
# 62.26    3
# 75.55    3
# 84.53    3
# 78.76    3
#         ..
# 61.09    1
# 65.77    1
# 37.87    1
# 60.91    1
# 45.01    1
# Name: Site_Time, Length: 900, dtype: int64

# %%
Ad.corr()
# Out:
#            Site_Time       Age  DailyTime
# Site_Time   1.000000 -0.331513   0.518658
# Age        -0.331513  1.000000  -0.367209
# DailyTime   0.518658 -0.367209   1.000000

# %%
sns.heatmap(Ad.corr(), annot=True)

# %%
sns.heatmap(Ad.corr(), cmap="YlGnBu")

# %%
sns.pairplot(Ad)

# %%
sns.scatterplot(x="Age", y="DailyTime", data=Ad)

# %%
sns.lmplot(x="Age", y="DailyTime", data=Ad)

# %%
sns.scatterplot(x="Age", y="DailyTime", hue="Gender", data=Ad)

# %%
sns.lmplot(x = "Age", y= "DailyTime", hue="Gender", data = Ad)

# %%
sns.countplot(x='AdClicking', data=Ad)

# %%
sns.countplot(x='AdClicking', data=Ad, color='b')

# %%
Ad_day=Ad.groupby("AdClicking")
Ad_day.mean()
# Out:
#             Site_Time     Age  DailyTime
# AdClicking
# No           76.85462  31.684  214.51374
# Yes          53.14578  40.334  145.48646

# %%
sns.boxplot(x="Gender", y="DailyTime", data=Ad)

# %%
sns.boxplot(x="Gender", y="DailyTime", hue="AdClicking", data=Ad)

# %%
Ad_Ad3_Ad=Ad.nlargest(3, "Site_Time")
Ad_Ad3_Ad
# Out:
#      Site_Time  Age  DailyTime  Gender AdClicking
# 533      91.43   39     209.91    Male         No
# 860      91.37   45     182.65    Male        Yes
# 927      91.15   38     184.98  Female         No
